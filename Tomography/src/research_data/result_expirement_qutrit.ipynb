# %%
import sys
# на уровень выше из research_rank/
sys.path.insert(0, '..')
from Tomography_qutrit import*
from numpy import diag, pi

# %%
protocol = [diag((1,1,1)), Gl_2(pi / 8), Gl_8(0) @ Gl_2(pi / 8)]
Fedorov = tomography_pol_qutrit(protocol)

# %% [markdown]
# ## Протокол с пластинкой $\frac{\lambda}{4}$

# %%
print("\n\n\n HH  \n\n\n")
# # 20 повторения по 10с при HWP_p под 0
# Noise
# 1.2 3.15 233.6
# 72.7 5.35 1.15
# Калибровка      10.7 100.1 69.15
n_hh = 1.2 / 233.6
n_hv_1 = 3.15 / 233.6
n_hv_2 = 5.35 / 72.7
n_vv = 1.15 / 72.7

sigma1 = full(5, 10.7 - 69.15 * n_hh)
sigma2 = full(5, (100.1 - 10.7 * n_hv_1 - 69.15 * n_hv_2)/2)
sigma3 = full(5, 69.15 - 10.7 * n_vv)

protocol = [Gl_4(0), Gl_4(pi / 8), Gl_4(3 * pi / 8), Gl_4(5 * pi / 8), Gl_4(7 * pi / 8)]
Start_protocol = tomography_pol_qutrit(protocol)
phh = Fedorov.hh

khh = array([
72.7 - 1.15 * n_hh, 5.35 - 5.35,	1.15 - 72. * n_vv,
44.6 - 20.95 * n_hh, 58.1 - 44.6 * n_hv_1 - 20.95 * n_hv_2, 20.95 - 44.6 * n_vv,
34.55 - 12.95 * n_hh, 94.55 - 34.55 * n_hv_1 - 12.95 * n_hv_2, 12.95 - 34.55 * n_vv,
39.9 - 10.7 * n_hh, 78.3 - 39.9 * n_hv_1 - 10.7 * n_hv_2, 10.7 - 39.9 * n_vv,
37.35 - 22.3 * n_hh, 73.65 - 37.35 * n_hv_1 - 22.3 * n_hv_2, 22.3 - 37.35 * n_vv
])
Start_protocol.experiment(khh, phh, sigma1, sigma2, sigma3)


print("\n\n\n VV  \n\n\n")
# # 20 повторения по 10с при HWP_p под 0
# Noise
# 0.45 1.65 186.9
# 67.85 4.6 1.5
# Калибровка      21.55 92.1 45.35
n_hh = 0.45 / 186.59
n_hv_1 = 1.9 / 186.9
n_hv_2 = 4.6 / 67.85
n_vv = 1.5 / 67.85

sigma1 = full(5, 21.55 - 45.35 * n_hh)
sigma2 = full(5, (92.1 - 21.55 * n_hv_1 - 45.35 * n_hv_2)/2)
sigma3 = full(5, 45.35 - 21.55 * n_vv)

protocol = [Gl_4(0), Gl_4(pi / 8), Gl_4(3 * pi / 8), Gl_4(5 * pi / 8), Gl_4(7 * pi / 8)]
Start_protocol = tomography_pol_qutrit(protocol)
phh = Fedorov.vv

khh = array([
0.45 - 186.9 * n_hh, 1.65 - 1.65,	186.9 - 0.45 * n_vv,
3.95 - 108.6 * n_hh, 88.9 - 3.95 * n_hv_1 - 108.6 * n_hv_2, 108.6 - 3.95 * n_vv,
5.25 - 103.55 * n_hh, 91.95 - 5.25 * n_hv_1 - 103.55 * n_hv_2, 103.55 - 5.25 * n_vv,
3.1 - 108.95 * n_hh, 89.45 - 3.1 * n_hv_1 - 108.95 * n_hv_2, 108.95 - 3.1 * n_vv,
6.2 - 107.1 * n_hh, 86.35 - 6.2 * n_hv_1 - 107.1 * n_hv_2, 107.1 - 6.2 * n_vv
])
Start_protocol.experiment(khh, phh, sigma1, sigma2, sigma3)

print("\n\n\n AA  \n\n\n")
# # 20 повторения по 10с при HWP_p под 0 HWP_B1 под 24.5
# Noise
# 0.1 4.1 177.8
# 45.9 15.45 0.65

n_hh =  0.1 / 177.8
n_hv_1 = 4.1 / 177.8
n_hv_2 = 5.45 / 45.9
n_vv = 0.65 / 45.9


sigma1 = full(5, 12.45 - 39.05 * n_hh)
sigma2 = full(5, (134.2 - 12.45 * n_hv_1 - 39.05 * n_hv_2)/2)
sigma3 = full(5, 39.05 - 12.45 * n_vv)

protocol = [Gl_4(0), Gl_4(pi / 8), Gl_4(3 * pi / 8), Gl_4(5 * pi / 8), Gl_4(7 * pi / 8)]
Start_protocol = tomography_pol_qutrit(protocol)
phh = Fedorov.aa

khh = array([
12.45 - 39.05 * n_hh, 134.2 - 12.45 * n_hv_1 - 39.05 * n_hv_2,	39.05 - 12.45 * n_vv,
3.2 - 99.5 * n_hh, 108.05 - 3.2 * n_hv_1 - 99.5 * n_hv_2, 99.5 - 3.2 * n_vv,
26.4 - 13.8 * n_hh, 114.5 - 26.4 * n_hv_1 - 13.8 * n_hv_2, 13.8 - 26.4 * n_vv,
4.2 - 78.9 * n_hh, 143.6 - 4.2  * n_hv_1 - 78.9 * n_hv_2, 78.9 - 4.2  * n_vv,
29.7 - 6.4 * n_hh, 116.75 - 29.7 * n_hv_1 - 6.4 * n_hv_2, 6.4 - 29.7 * n_vv
])
Start_protocol.experiment(khh, phh, sigma1, sigma2, sigma3)

print("\n\n\n DD  \n\n\n")
# # 20 повторения по 10с при HWP_p под 0
# Noise
# 0.5 4.05 181.35
# 71.7 3.25 1.1

n_hh = 0.5 / 181.35
n_hv_1 = 4.05 / 181.35
n_hv_2 = 3.25 / 71.7
n_vv = 1.1 / 71.7

sigma1 = full(5, 18.5 - 43.65 * n_hh)
sigma2 = full(5, (152 - 18.5 * n_hv_1 - 43.65 * n_hv_2)/2)
sigma3 = full(5, 43.65 - 18.5 * n_vv)

protocol = [Gl_4(0), Gl_4(pi / 8), Gl_4(3 * pi / 8), Gl_4(5 * pi / 8), Gl_4(7 * pi / 8)]
Start_protocol = tomography_pol_qutrit(protocol)
phh = Fedorov.dd

khh = array([
18.5 - 43.65 * n_hh, 152 - 18.5 * n_hv_1 - 43.65 * n_hv_2,	43.65 - 18.5 * n_vv,
41.35 - 16.1 * n_hh, 90.1 - 41.35 * n_hv_1 - 16.1 * n_hv_2, 16.1 - 41.35 * n_vv,
5.4 - 115.3 * n_hh, 83.45 - 5.4 * n_hv_1 - 115.3 * n_hv_2, 115.3 - 5.4 * n_vv,
44.15 - 8.55 * n_hh, 83.65 - 44.15 * n_hv_1 - 8.55 * n_hv_2, 8.55 - 44.15 * n_vv,
7.4 - 94.65 * n_hh, 103.65 - 7.4 * n_hv_1 - 94.65 * n_hv_2, 94.65 - 7.4 * n_vv
])
Start_protocol.experiment(khh, phh, sigma1, sigma2, sigma3)


print("\n\n\n LL \n\n\n")
# # 20 повторения по 10с при HWP_p под 0 HWP_B1 под 24.5
# Noise
# 0 4.1 169.5
# 44.75 15.45 0.55

n_hh =  0 / 169.5
n_hv_1 = 5 / 169.5
n_hv_2 = 6.3 / 44.75
n_vv = 0.55 / 44.75

sigma1 = full(5, 10.75 - 41.45 * n_hh)
sigma2 = full(5, (142.85 - 10.75 * n_hv_1 - 41.45 * n_hv_2)/2)
sigma3 = full(5, 41.45 - 10.75 * n_vv)

protocol = [Gl_4(0), Gl_4(pi / 8), Gl_4(3 * pi / 8), Gl_4(5 * pi / 8), Gl_4(7 * pi / 8)]
Start_protocol = tomography_pol_qutrit(protocol)
phh = Fedorov.ll

khh = array([
10.75 - 41.45 * n_hh, 142.85 - 10.75 * n_hv_1 - 41.45 * n_hv_2,	41.45 - 10.75 * n_vv,
0.35 - 129.15 * n_hh, 55.45 - 0.35 * n_hv_1 - 129.15 * n_hv_2, 129.15 - 0.35 * n_vv,
1.45 - 113.8 * n_hh, 81.1 - 1.45 * n_hv_1 - 113.8 * n_hv_2, 113.8 - 1.45 * n_vv,
34.3 - 1.45 * n_hh, 57.3 - 34.3  * n_hv_1 - 1.45 * n_hv_2, 1.45 - 34.3  * n_vv,
27.8 - 9.2 * n_hh, 90.75 - 27.8 * n_hv_1 - 9.2 * n_hv_2, 9.2 - 27.8 * n_vv
])
Start_protocol.experiment(khh, phh, sigma1, sigma2, sigma3)

print("\n\n\n RR \n\n\n")
# # 20 повторения по 10с при HWP_p под 0 HWP_B1 под 24.5
# Noise
# 0.05 9.65 154
# 42.2 12.75 0.4

n_hh = 0 / 154
n_hv_1 = 4 / 154
n_hv_2 = 7.45 / 42.2
n_vv = 0.4 / 42.2

sigma1 = full(5, 9.75 - 29.55 * n_hh)
sigma2 = full(5, (131.7 - 9.75 * n_hv_1 - 29.55 * n_hv_2)/2)
sigma3 = full(5, 29.55 - 9.75 * n_vv)

protocol = [Gl_4(0), Gl_4(pi / 8), Gl_4(3 * pi / 8), Gl_4(5 * pi / 8), Gl_4(7 * pi / 8)]
Start_protocol = tomography_pol_qutrit(protocol)
phh = Fedorov.rr

khh = array([
9.75 - 29.55 * n_hh, 131.7 - 9.75 * n_hv_1 - 29.55 * n_hv_2,	29.55 - 9.75 * n_vv,
30.2 - 4.35 * n_hh, 51.1 - 30.2 * n_hv_1 - 4.35 * n_hv_2, 4.35 - 30.2 * n_vv,
28.1 - 2.25 * n_hh, 75.05 - 28.1 * n_hv_1 - 2.25 * n_hv_2, 2.25 - 28.1 * n_vv,
0.4 - 125.9 * n_hh, 43.2 - 0.4 * n_hv_1 - 125.9  * 0, 125.9  - 0.4  * n_vv,
1.45 - 94.35 * n_hh, 94.8 - 1.45 * n_hv_1 - 94.35 * n_hv_2, 94.35 - 1.45 * n_vv
])
Start_protocol.experiment(khh, phh, sigma1, sigma2, sigma3)


print("\n\n\n VV+iHH \n\n\n")
# # 20 повторения по 10с при HWP_p под 0 HWP_B1 под 24.5
# Noise
# 39.05 5.4 30.9
# 0.55 170.7 1.5

# Калибровка
# 22.85 87.75 26.8
n_hh = 0.55 / 225.45
n_hv = 5.4 / (39.05 + 30.9)
n_vv = 1.5 / 225.45


sigma1 = full(5, 22.85 - 87.75 * n_hh)
sigma2 = full(5, (87.75 - (22.85 + 26.8) * n_hv)/2)
sigma3 = full(5, 26.8 - 87.75 * n_vv)

protocol = [Gl_4(0), Gl_4(pi / 8), Gl_4(3 * pi / 8), Gl_4(5 * pi / 8), Gl_4(7 * pi / 8)]
Start_protocol = tomography_pol_qutrit(protocol)
phh = (Fedorov.vv + 1j*Fedorov.hh)/2**0.5

khh = array([
39.05 - 5.4 * n_hh, 5.4 - (39.05 + 30.9) * n_hv,	30.9 - 5.4 * n_vv,
13.7 - 150.9 * n_hh,  150.9 - (13.7 + 11.9) * n_hv,	11.9 - 150.9 * n_vv,
36.85 - 6.1 * n_hh, 6.1- (36.85 + 33.95) * n_hv, 33.95 - 6.1 * n_vv,
37 - 5.9 * n_hh,  5.9 - (37 + 36.85) * n_hv,  36.85  - 5.9 * n_vv,
10.65 - 165.6 * n_hh,  165.6 - (10.65 + 12.5) * n_hv,   12.5 - 165.6 * n_vv
])
Start_protocol.experiment(khh, phh, sigma1, sigma2, sigma3)

print("\n\n\n DD + iAA \n\n\n")
# # 20 повторения по 10с при HWP_p под 0
# Noise
# 29.65 3.1 80.7
# 2.35 183.2 3.4

n_hh = 2.35 / 183.2
n_hv = 7.5 / (29.65 + 80.7)
n_vv = 3.4 / 183.2
sigma1 = full(5, 19.1 - 119.35 * n_hh)
sigma2 = full(5, (119.35 - (19.1 + 61.75) * n_hv)/2)
sigma3 = full(5, 61.75 - 119.35 * n_vv)

protocol = [Gl_4(0), Gl_4(pi / 8), Gl_4(3 * pi / 8), Gl_4(5 * pi / 8), Gl_4(7 * pi / 8)]
Start_protocol = tomography_pol_qutrit(protocol)
phh= (Fedorov.dd + 1j * Fedorov.aa)/2**0.5

khh = array([
19.1 - 119.35 * n_hh, 119.35 - (19.1 + 61.75) * n_hv,	61.75 - 119.35 * n_vv,
8.55 - 153.75 * n_hh, 153.75 - (8.55 + 29.95) * n_hv,	29.95 - 153.75 * n_vv,
14.6 - 131.55 * n_vv, 131.55 - (14.6 + 30.2) * n_hv, 30.2 - 131.55 * n_hh,
28.15 - 7.25 * n_hh, 7.25 - (28.15 + 94) * n_hv, 94 - 7.25 * n_vv,
34 - 13 * n_hh, 13 - (34 + 77.8) * n_hv, 77.8 - 13 * n_vv
])
Start_protocol.experiment(khh, phh, sigma1, sigma2, sigma3)

print("\n\n\n RR-iLL \n\n\n")
# # 20 повторения по 10с при HWP_p под 0 HWP_B1 под 24.5
# Noise
# 42.05 7.7 33.09
# 1.15 225.75 2.75

n_hh = 1.15 / 225.75
n_hv = 7.7 / (33.09 + 42.05)
n_vv = 2.75 / 225.75


sigma1 = full(5, 18.3 - 171.15 * n_hh)
sigma2 = full(5, (171.15 - (18.3 + 13.7) * n_hv)/2)
sigma3 = full(5, 13.7 - 171.15 * n_vv)

protocol = [Gl_4(0), Gl_4(pi / 8), Gl_4(3 * pi / 8), Gl_4(5 * pi / 8), Gl_4(7 * pi / 8)]
Start_protocol = tomography_pol_qutrit(protocol)
phh = (Fedorov.rr - 1j*Fedorov.ll)/2**0.5

khh = array([
18.3 - 171.15 * n_hh,   171.15 - (18.3 + 13.7) * n_hv,	13.7 - 171.15 * n_vv,
18.3 - 151.45 * n_hh,  151.45 - (18.3 + 13.75) * n_hv,	13.75 - 151.45 * n_vv,
42.05 - 7.7 * n_hh, 7.7- (33.09 + 42.05) * n_hv,    33.09 - 7.7 * n_vv,
17.55 - 150.4 * n_hh,  150.4 - (17.55 + 21.1) * n_hv,  21.1  - 150.4 * n_vv,
42 - 5.85 * n_hh,  5.85 - 5.85,   42.1 - 42 * n_vv
])
Start_protocol.experiment(khh, phh, sigma1, sigma2, sigma3)
# Out:
#  HH
#
#
#
# Fidelity between start matrix density and matrix pseudoinversion = 0.9122538701122611
# Finish fidelity = 0.9967815396573171
#
#
#
#  VV
#
#
#
# Fidelity between start matrix density and matrix pseudoinversion = 0.9695238113761153
# Finish fidelity = 0.9914801838764165
#
#
#
#  AA
#
#
#
# Fidelity between start matrix density and matrix pseudoinversion = 0.9884471164805763
# Finish fidelity = 0.9927704103013665
#
#
#
#  DD
#
#
#
# Fidelity between start matrix density and matrix pseudoinversion = 0.9751892088841566
# Finish fidelity = 0.9907765850505926
#
#
#
#  LL
#
#
#
# Fidelity between start matrix density and matrix pseudoinversion = 0.9876287396584332
# Finish fidelity = 0.9935249170068504
#
#
#
#  RR
#
#
#
# Fidelity between start matrix density and matrix pseudoinversion = 0.9779846530497232
# Finish fidelity = 0.9938676103010147
#
#
#
#  VV+iHH
#
#
#
# Fidelity between start matrix density and matrix pseudoinversion = 0.8804967090753414
# Finish fidelity = 0.9960991770909827
#
#
#
#  DD + iAA
#
#
#
# Fidelity between start matrix density and matrix pseudoinversion = 0.9896148417884922
# Finish fidelity = 0.9874013882039995
#
#
#
#  RR-iLL
#
#
#
# Fidelity between start matrix density and matrix pseudoinversion = 0.9652868842320547
# Finish fidelity = 0.9990809900149749

# %% [markdown]
# ## Протокол с пластинкой $\frac{\lambda}{8}$

# %%
protocol = [diag((1,1,1)), Gl_2(pi / 8), Gl_4(pi / 8), Gl_2(pi / 8) @ Gl_4(-45 * pi / 180) @ Gl_2(11.25 * pi / 180) @ Gl_4(-45 * pi / 180)]
Fedorov_4 = tomography_pol_qutrit(protocol)
protocol = [diag((1,1,1)), Gl_2(pi / 8), Gl_2(pi / 8) @ Gl_4(-45 * pi / 180) @ Gl_2(11.25 * pi / 180) @ Gl_4(-45 * pi / 180)]
Fedorov_3 = tomography_pol_qutrit(protocol)

print("\n\n\n VV Fed \n\n\n")
# 20 повторения по 10с при HWP_p под 0
# Noise
# 0.25 2.5 169.55
# 63 3.8 1.4

n_hh = 0.25 / 169.55
n_hv_1 = 1.9 / 169.55
n_hv_2 = 3.8 / 63
n_vv = 1.4 / 63
sigma1 = full(3, 20.75 - 40.15 * n_hh)
sigma2 = full(3, (89.4 - 20.75 * n_hv_1 - 40.15 * n_hv_2)/2)
sigma3 = full(3, 40.15 - 20.75 * n_vv)

phh= Fedorov.vv
khh = array([
0.25 - 169.55 * n_hh, 1.9 - 1.9,	169.55 - 0.25 * n_vv,
20.75 - 40.15 * n_hh, 89.4 - 20.75 * n_hv_1 - 40.15 * n_hv_2, 40.15 - 20.75 * n_vv,
17.15 - 30.15 * n_hh, 106.6 - 17.15 * n_hv_1 - 30.15 * n_hv_2, 30.15 - 17.15 * n_vv
])
Fedorov_3.experiment(khh, phh, sigma1, sigma2, sigma3)

phh= Fedorov.vv

sigma1 = full(4, 20.75 - 40.15 * n_hh)
sigma2 = full(4, (89.4 - 20.75 * n_hv_1 - 40.15 * n_hv_2)/2)
sigma3 = full(4,  40.15 - 20.75 * n_vv)

khh = array([
0.25 - 169.55 * n_hh, 1.9 - 1.9,	169.55 - 0.25 * n_vv,
20.75 - 40.15 * n_hh, 89.4 - 20.75 * n_hv_1 - 40.15 * n_hv_2, 40.15 - 20.75 * n_vv,
3.65 - 96.45 * n_hh, 80 - 3.65 * n_hv_1 - 96.45 * n_hv_2, 96.45 - 3.65 * n_vv,
17.15 - 30.15 * n_hh, 106.6 - 17.15 * n_hv_1 - 30.15 * n_hv_2, 30.15 - 17.15 * n_vv
                 ])
Fedorov_4.experiment(khh, phh, sigma1, sigma2, sigma3)

print("\n\n\n HH Fed \n\n\n")
# 20 повторения по 10с при HWP_p под 0
# Noise
# 0.65 6.15 246.4
# 70 4.8 1.35

n_hh = 0.65 / 246.4
n_hv_1 = 6.15 / 246.4
n_hv_2 = 4.8 / 70
n_vv = 1.35 / 70
sigma1 = full(3, 12.95 - 67.5 * n_hh)
sigma2 = full(3, (97 - 12.95 * n_hv_1 - 67.5 * n_hv_2)/2)
sigma3 = full(3, 67.5 - 12.95 * n_vv)

phh= Fedorov.hh
khh = array([
70 - 1.35 * n_hh, 1.9 - 1.9,	1.35 - 70 * n_vv,
12.95 - 67.5 * n_hh, 97 - 12.95 * n_hv_1 - 67.5 * n_hv_2, 67.5 - 12.95 * n_vv,
12.8 - 71.2 * n_hh, 109.25 - 12.8 * n_hv_1 - 71.2 * n_hv_2, 71.2 - 12.8 * n_vv
])
Fedorov_3.experiment(khh, phh, sigma1, sigma2, sigma3)

phh= Fedorov.hh

sigma1 = full(4, 12.95 - 67.5 * n_hh)
sigma2 = full(4, (97 - 12.95 * n_hv_1 - 67.5 * n_hv_2)/2)
sigma3 = full(4,  67.5 - 12.95 * n_vv)

khh = array([
70 - 1.35 * n_hh, 1.9 - 1.9,	1.35 - 70 * n_vv,
12.95 - 67.5 * n_hh, 97 - 12.95 * n_hv_1 - 67.5 * n_hv_2, 67.5 - 12.95 * n_vv,
42.05 - 18.9 * n_hh, 52.45 - 42.05 * n_hv_1 - 18.9 * n_hv_2, 18.9 - 42.05 * n_vv,
12.8 - 71.2 * n_hh, 109.25 - 12.8 * n_hv_1 - 71.2 * n_hv_2, 71.2 - 12.8 * n_vv
                 ])
Fedorov_4.experiment(khh, phh, sigma1, sigma2, sigma3)

protocol = [diag((1,1,1)), Gl_2(pi / 8), Gl_4(pi / 8), Gl_2(pi / 8) @ Gl_4(-45 * pi / 180) @ Gl_2(11.25 * pi / 180) @ Gl_4(-45 * pi / 180)]
Fedorov_4 = tomography_pol_qutrit(protocol)
protocol = [diag((1,1,1)), Gl_2(pi / 8), Gl_2(pi / 8) @ Gl_4(-45 * pi / 180) @ Gl_2(11.25 * pi / 180) @ Gl_4(-45 * pi / 180)]
Fedorov_3 = tomography_pol_qutrit(protocol)


print("\n\n\n AA Fed \n\n\n")
# 20 повторения по 10с при HWP_p под 0
# Noise
# 0 3.15 163.85
# 44.95 5.25 0.2

n_hh = 0 / 163.85
n_hv_1 = 3.15 / 163.85
n_hv_2 = 5.1 / 44.95
n_vv = 0.2 / 44.95
sigma1 = full(3, 9.75 - 53.9 * n_hh)
sigma2 = full(3, (134.1 - 9.75 * n_hv_1 - 53.9 * n_hv_2)/2)
sigma3 = full(3, 53.9 - 9.75 * n_vv)

phh= Fedorov.aa
khh = array([
9.75 - 53.9 * n_hh, 134.1 - 9.75 * n_hv_1 - 53.9 * n_hv_2, 53.9 - 9.75 * n_vv,
0 , 3.15 - 3.15, 163.85 - 0 * n_vv,
30.2 - 4 * n_hh, 80.55 - 30.2 * n_hv_1 - 4 * n_hv_2, 4 - 30.2 * n_vv
])
Fedorov_3.experiment(khh, phh, sigma1, sigma2, sigma3)

phh= Fedorov.aa

sigma1 = full(4, 9.75 - 53.9 * n_hh)
sigma2 = full(4, (134.1 - 9.75 * n_hv_1 - 53.9 * n_hv_2)/2)
sigma3 = full(4,  53.9 - 9.75 * n_vv)

khh = array([
9.75 - 53.9 * n_hh, 134.1 - 9.75 * n_hv_1 - 53.9 * n_hv_2, 53.9 - 9.75 * n_vv,
0 , 3.15 - 3.15, 163.85 - 0  * n_vv,
3.05 - 96.25 * n_hh, 102.8 - 3.05 * n_hv_1 - 96.25 * n_hv_2, 96.25 - 3.05 * n_vv,
30.2 - 4 * n_hh, 100.55 - 30.2 * n_hv_1 - 4 * n_hv_2, 4 - 30.2 * n_vv
                 ])
Fedorov_4.experiment(khh, phh, sigma1, sigma2, sigma3)

protocol = [diag((1,1,1)), Gl_2(pi / 8), Gl_4(pi / 8), Gl_2(pi / 8) @ Gl_4(-45 * pi / 180) @ Gl_2(11.25 * pi / 180) @ Gl_4(-45 * pi / 180)]
Fedorov_4 = tomography_pol_qutrit(protocol)
protocol = [diag((1,1,1)), Gl_2(pi / 8), Gl_2(pi / 8) @ Gl_4(-45 * pi / 180) @ Gl_2(11.25 * pi / 180) @ Gl_4(-45 * pi / 180)]
Fedorov_3 = tomography_pol_qutrit(protocol)

print("\n\n\n DD Fed \n\n\n")
# 20 повторения по 10с при HWP_p под 0
# Noise
# 0.35 4.3 217.25
# 66.55 5.45 1

n_hh = 0.35 / 217.25
n_hv_1 = 4.3 / 217.25
n_hv_2 = 5.45 / 66.55
n_vv = 1 / 66.55
sigma1 = full(3, 22.95 - 38.2 * n_hh)
sigma2 = full(3, (82.6 - 22.95 * n_hv_1 - 38.2 * n_hv_2)/2)
sigma3 = full(3, 38.2 - 22.95 * n_vv)

phh= Fedorov.dd
khh = array([
22.95 - 38.2 * n_hh, 82.6 - 22.95 * n_hv_1 - 38.2 * n_hv_2,	38.2 - 22.95 * n_vv,
66.55 - 1 * n_hh, 5.45 - 5.45, 1 - 66.55 * n_vv,
3.15 - 161.7 * n_hh, 46.1 - 3.15 * n_hv_1 - 161.7 * n_hv_2, 161.7 - 3.15 * n_vv
])
Fedorov_3.experiment(khh, phh, sigma1, sigma2, sigma3)

phh = Fedorov.dd

sigma1 = full(4, 22.95 - 38.2 * n_hh)
sigma2 = full(4, (82.6 - 22.95 * n_hv_1 - 38.2 * n_hv_2)/2)
sigma3 = full(4,  38.2 - 22.95 * n_vv)

khh = array([
22.95 - 38.2 * n_hh, 82.6 - 22.95 * n_hv_1 - 38.2 * n_hv_2,	38.2 - 22.95 * n_vv,
66.55 - 1 * n_hh, 5.45 - 5.45, 1 - 66.55 * n_vv,
36.9 - 12.5 * n_hh, 80.15 - 36.9 * n_hv_1 - 12.5 * n_hv_2, 12.5 - 36.9 * n_vv,
3.15 - 161.7 * n_hh, 46.1 - 3.15 * n_hv_1 - 161.7 * n_hv_2, 161.7 - 3.15 * n_vv
                 ])
Fedorov_4.experiment(khh, phh, sigma1, sigma2, sigma3)

print("\n\n\n RR Fed \n\n\n")
# 20 повторения по 10с при HWP_p под 0
# Noise
# 0.05 5.2 162.5
# 45.2 8.05 0.3

n_hh = 0.05 / 162.5
n_hv_1 = 5.2 / 162.5
n_hv_2 = 8.05 / 45.2
n_vv = 0.3 / 45.2

sigma1 = full(3, 14.05 - 38.1 * n_hh)
sigma2 = full(3, (133.6 - 14.05 * n_hv_1 -  38.1 * n_hv_2)/2)
sigma3 = full(3, 38.1 - 14.05 * n_vv)

phh= Fedorov.rr
khh = array([
11.15 - 34.15 * n_hh, 149.05 - 11.15 * n_hv_1 - 34.15  * n_hv_2,	34.15  - 11.15 * n_vv,
14.05 - 38.1 * n_hh, 133.6 - 14.05 * n_hv_1 -  38.1 * n_hv_2,  38.1 - 14.05 * n_vv,
0.5 - 124.75 * n_hh, 60.4 - 0.5  * n_hv_1 - 124.75 * n_hv_2, 124.75 - 0.5  * n_vv
])
Fedorov_3.experiment(khh, phh, sigma1, sigma2, sigma3)

phh= Fedorov.rr

sigma1 = full(4, 14.05 - 38.1 * n_hh)
sigma2 = full(4, (133.6 - 14.05 * n_hv_1 -  38.1 * n_hv_2)/2)
sigma3 = full(4,  38.1 - 14.05 * n_vv)

khh = array([
11.15 - 34.15 * n_hh, 149.05 - 11.15 * n_hv_1 - 34.15  * n_hv_2,	34.15  - 11.15 * n_vv,
14.05 - 38.1 * n_hh, 133.6 - 14.05 * n_hv_1 -  38.1 * n_hv_2,  38.1 - 14.05 * n_vv,
32.6 - 4.25 * n_hh, 60.25 - 32.6 * n_hv_1 - 4.25 * n_hv_2, 4.25 - 32.6 * n_vv,
0.5 - 124.75 * n_hh, 60.4 - 0.5  * n_hv_1 - 124.75 * n_hv_2, 124.75 - 0.5  * n_vv
                 ])
Fedorov_4.experiment(khh, phh, sigma1, sigma2, sigma3)


print("\n\n\n LL \n\n\n")
# 20 повторения по 10с при HWP_p под 45
# Noise
# 0.7 3.55 240.45
# 62.95 4.1  1.45

n_hh = 0.7 / 240.45
n_hv_1 = 3.55 / 240.45
n_hv_2 = 4.1 / 62.95
n_vv = 1.45 / 62.95
sigma1 = full(3, 20.15 - 63.85 * n_hh)
sigma2 = full(3, (89.1 - 20.15 * n_hv_1 - 63.85 * n_hv_2)/2)
sigma3 = full(3, 63.85 - 10.15 * n_vv)

phh= Fedorov.ll
khh = array([

20.15 - 63.85 * n_hh, 89.1 - 20.15 * n_hv_1 - 63.85 * n_hv_2,	63.85 - 10.15 * n_vv,
16.1 - 58.4 * n_hh, 92.85 - 16.1 * n_hv_1 - 58.4 * n_hv_2,	58.3 - 16.1 * n_vv,
48 - 7.05 * n_hh, 42 - 48 * n_hv_1 - 7.05 * n_hv_2, 7.05 - 48 * n_vv
])
Fedorov_3.experiment(khh, phh, sigma1, sigma2, sigma3)

sigma1 = full(4, 20.15 - 63.85 * n_hh)
sigma2 = full(4, (89.1 - 20.15 * n_hv_1 - 63.85 * n_hv_2)/2)
sigma3 = full(4,  63.85 - 10.15 * n_vv)

khh = array([

20.15 - 63.85 * n_hh, 89.1 - 20.15 * n_hv_1 - 63.85 * n_hv_2,	63.85 - 10.15 * n_vv,
16.1 - 58.4 * n_hh, 92.85 - 16.1 * n_hv_1 - 58.4 * n_hv_2,	58.3 - 16.1 * n_vv,
9.05 - 120.85 * n_vv, 56 - 9.05 * n_hv_1 - 120.85 * n_hv_2, 120.85 - 9.05 * n_hh,
48 - 7.05 * n_hh, 42 - 48 * n_hv_1 - 7.05 * n_hv_2, 7.05 - 48 * n_vv
])
Fedorov_4.experiment(khh, phh, sigma1, sigma2, sigma3)

protocol = [diag((1,1,1)), Gl_2(pi/8), Gl_4(pi/8), Gl_2(pi/8) @ Gl_8(0)]
Fedorov_4 = tomography_pol_qutrit(protocol)
protocol = [diag((1,1,1)), Gl_2(pi/8), Gl_2(pi/8) @ Gl_8(0)]
Fedorov_3 = tomography_pol_qutrit(protocol)
print("\n\n\n VV+iHH \n\n\n")
# 20 повторения по 10с при HWP_p под 45
# Noise
# 30.95 3.45 72.7
# 1.9 158.95 4.7

n_hh = 1.9 / 158.95
n_hv = 3.45 / (30.95 + 72.7)
n_vv = 4.7 / 158.95
sigma1 = full(3, 12.9 - 97.6 * n_hh)
sigma2 = full(3, (97.6 - (12.9 + 45.45) * n_hv)/2)
sigma3 = full(3, 45.45 - 97.6 * n_vv)

phh= (Fedorov.vv + 1j * Fedorov.hh)/2**0.5
khh = array([

30.95 - 3.45 * n_hh, 3.45 - (30.95 + 72.7) * n_hv,	72.7 - 3.45 * n_vv,
12.9 - 97.6 * n_hh, 97.6 - (12.9 + 45.45) * n_hv,	45.45 - 97.6 * n_vv,
27.9 - 4.65 * n_hh, 4.65 - (27.9 + 85.55) * n_hv, 85.55 - 4.65 * n_vv
])
Fedorov_3.experiment(khh, phh, sigma1, sigma2, sigma3)

sigma1 = full(4, 12.9 - 97.6 * n_hh)
sigma2 = full(4, (97.6 - (12.9 + 45.45) * n_hv)/2)
sigma3 = full(4,  45.45 - 97.6 * n_vv)

khh = array([
30.95 - 3.45 * n_hh, 3.45 - (30.95 + 72.7) * n_hv,	72.7 - 3.45 * n_vv,
12.9 - 97.6 * n_hh, 97.6 - (12.9 + 45.45) * n_hv,	45.45 - 97.6 * n_vv,
8.6 - 107.2 * n_vv, 107.2 - (8.6 + 22.8) * n_hv, 22.8 - 107.2 * n_hh,
27.9 - 4.65 * n_hh, 4.65 - (27.9 + 85.55) * n_hv, 85.55 - 4.65 * n_vv
])
Fedorov_4.experiment(khh, phh, sigma1, sigma2, sigma3)

print("\n\n\n DD+iAA \n\n\n")
# 20 повторения по 10с при HWP_p под 0
# Noise
# 24.2 3.1 92.95
# 2.75 169.05 2.8

n_hh = 2.75 / 169.05
n_hv = 3.1 / (24.2 + 92.95)
n_vv = 2.8 / 169.05
sigma1 = full(3, 10 - 107.5 * n_hh)
sigma2 = full(3, (107.5 - (10 + 42.2) * n_hv)/2)
sigma3 = full(3, 42.2 - 107.5 * n_vv)

phh= (Fedorov.dd + 1j * Fedorov.aa)/2**0.5
khh = array([
10 - 107.5 * n_hh, 107.5 - (10 + 42.2) * n_hv,	42.2 - 107.5 * n_vv,
24.2 - 3.1 * n_hh, 3.1 - (92.95 + 24.2) * n_hv,	92.95 - 3.1 * n_vv,
23.5 - 58.35 * n_hh, 58.35 - (23.05 + 48.05) * n_hv, 48.05 - 58.35 * n_vv
])
Fedorov_3.experiment(khh, phh, sigma1, sigma2, sigma3)

sigma1 = full(4, 10 - 107.5 * n_hh)
sigma2 = full(4, (107.5 - (10 + 42.2) * n_hv)/2)
sigma3 = full(4, 42.2 - 107.5 * n_vv)

khh = array([
10 - 107.5 * n_hh, 107.5 - (10 + 42.2) * n_hv,	42.2 - 107.5 * n_vv,
24.2 - 3.1 * n_hh, 3.1 - (92.95 + 24.2) * n_hv,	92.95 - 3.1 * n_vv,
7.55 - 127.8 * n_vv, 127.8 - (7.55 + 29.85) * n_hv, 29.85 - 127.8 * n_hh,
23.5 - 58.35 * n_hh, 58.35 - (23.05 + 48.05) * n_hv, 48.05 - 58.35 * n_vv
])
Fedorov_4.experiment(khh, phh, sigma1, sigma2, sigma3)

protocol = [diag((1,1,1)), Gl_2(pi / 8), Gl_4(pi / 8), Gl_2(pi / 8) @ Gl_4(-45 * pi / 180) @ Gl_2(11.25 * pi / 180) @ Gl_4(-45 * pi / 180)]
Fedorov_4 = tomography_pol_qutrit(protocol)
protocol = [diag((1,1,1)), Gl_2(pi / 8), Gl_2(pi / 8) @ Gl_4(-45 * pi / 180) @ Gl_2(11.25 * pi / 180) @ Gl_4(-45 * pi / 180)]
Fedorov_3 = tomography_pol_qutrit(protocol)

print("\n\n\n RR - iLL \n\n\n")
# 20 повторения по 10с при HWP_p под 45
# Noise
# 29.55 7.8 81.45
# 3.65 160.15 13.2

n_hh = 0 / 160.15
n_hv = 0 / (29.55 + 81.45)
n_vv = 0 / 160.15
sigma1 = full(3, 16.05 - 89.9 * n_hh)
sigma2 = full(3, (89.9 - (16.05 + 46.8) * n_hv)/2)
sigma3 = full(3, 46.8 - 89.9 * n_vv)

phh= (Fedorov.rr - 1j * Fedorov.ll)/2**0.5
khh = array([
16.05 - 89.9 * n_hh, 89.9 - (16.05 + 46.8) * n_hv,	46.8 - 89.9 * n_vv,
15.15 - 76.4 * n_hh, 76.4 - (15.15 + 42.1) * n_hv,	42.1 - 76.4 * n_vv,
20.85 - 44.15 * n_hh, 44.15 - (20.85 + 53) * n_hv, 53 - 44.15 * n_vv
])
Fedorov_3.experiment(khh, phh, sigma1, sigma2, sigma3)

sigma1 = full(4, 15.15 - 76.4 * n_hh)
sigma2 = full(4, (76.4 - (15.15 + 42.1) * n_hv)/2)
sigma3 = full(4,  42.1 - 76.4 * n_vv)

khh = array([
16.05 - 89.9 * n_hh, 89.9 - (16.05 + 46.8) * n_hv,	46.8 - 89.9 * n_vv,
15.15 - 76.4 * n_hh, 76.4 - (15.15 + 42.1) * n_hv,	42.1 - 76.4 * n_vv,
17.7 - 79.7 * n_vv, 79.7 - (17.7 + 61) * n_hv, 61 - 79.7 * n_hh,
20.85 - 44.15 * n_hh, 44.15 - (20.85 + 53) * n_hv, 53 - 44.15 * n_vv
])
Fedorov_4.experiment(khh, phh, sigma1, sigma2, sigma3)
# Out:
#  VV Fed
#
#
#
# Fidelity between start matrix density and matrix pseudoinversion = 0.9924784517090752
# Finish fidelity = 0.9937244094230958
# Fidelity between start matrix density and matrix pseudoinversion = 0.9903877486649345
# Finish fidelity = 0.9949234809321563
#
#
#
#  HH Fed
#
#
#
# Fidelity between start matrix density and matrix pseudoinversion = 0.9977047756128286
# Finish fidelity = 0.99965378863767
# Fidelity between start matrix density and matrix pseudoinversion = 0.9849665323959802
# Finish fidelity = 0.9985009372186102
#
#
#
#  AA Fed
#
#
#
# Fidelity between start matrix density and matrix pseudoinversion = 0.9786000476607539
# Finish fidelity = 0.9978627747646199
# Fidelity between start matrix density and matrix pseudoinversion = 0.9971021925969349
# Finish fidelity = 0.990926118553518
#
#
#
#  DD Fed
#
#
#
# Fidelity between start matrix density and matrix pseudoinversion = 0.8316045791608402
# Finish fidelity = 0.9938303209275053
# Fidelity between start matrix density and matrix pseudoinversion = 0.8663693438862676
# Finish fidelity = 0.9954267245044092
#
#
#
#  RR Fed
#
#
#
# Fidelity between start matrix density and matrix pseudoinversion = 0.9979949253811979
# Finish fidelity = 0.9912836818498234
# Fidelity between start matrix density and matrix pseudoinversion = 0.9871499030909388
# Finish fidelity = 0.9910226066823294
#
#
#
#  LL
#
#
#
# Fidelity between start matrix density and matrix pseudoinversion = 0.9989986007540782
# Finish fidelity = 0.985027365936225
# Fidelity between start matrix density and matrix pseudoinversion = 0.9881794926280737
# Finish fidelity = 0.9920620641846238
#
#
#
#  DD+iAA
#
#
#
# Fidelity between start matrix density and matrix pseudoinversion = 0.44738110291354544
# Finish fidelity = 0.004769077582967348
# Fidelity between start matrix density and matrix pseudoinversion = 0.9579674767521048
# Finish fidelity = 0.9950503698023576
#
#
#
#  RR - iLL
#
#
#
# Fidelity between start matrix density and matrix pseudoinversion = 0.498277962204128
# Finish fidelity = 0.9915627804161398
# Fidelity between start matrix density and matrix pseudoinversion = 0.9185884488954525
# Finish fidelity = 0.9938955887684294

# %%
# Out:
#  VV+iHH
#
#
#
# Fidelity between start matrix density and matrix pseudoinversion = 0.9871486646723818
# Finish fidelity = 0.9936999157414926
# Fidelity between start matrix density and matrix pseudoinversion = 0.9704215486518462
# Finish fidelity = 0.9937095355318633
